# %% [markdown]
# # Imagen Normal

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
path = r'C:/Users/david/OneDrive/Escritorio/IAC/VA_Presentacion/blur/examples/scarlett_johansson.png'
image = cv2.imread(path)

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # Video

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
video=cv2.VideoCapture(0)
while 1:
    ret, frame = video.read()
    cv2.imshow('sin filtro',frame)
    
    size = 4
    kernel = np.ones((size, size), np.float32) / (size ** 2)
    print(kernel)
    dst = cv2.filter2D(frame, -1, kernel)

    frame1 = cv2.cvtColor(dst, cv2.COLOR_BGR2RGB)
    cv2.imshow('Avatar filtro',frame1)
    
    frame2 = cv2.Canny(frame,10,200) 
    cv2.imshow('Filtro ¿?',frame2)

    #frame3 = cv2.cvtColor(dst, cv2.COLOR_BAYER_BG2BGR)
    #cv2.imshow('',frame3)

    key= cv2.waitKey(0)
# Out:
# [[0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]]
# [[0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]]
# [[0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]]
# [[0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]]
# [[0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]]
# [[0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]]
# [[0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]]
# [[0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
# ...

# %%
if cv2.waitKey(0):
    cv2.destroyAllWindows()

# %% [markdown]
# # IMAGEN BLUR

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
path = r'C:/Users/david/OneDrive/Escritorio/IAC/VA_Presentacion/blur/examples/chris_evans.png'
image = cv2.imread(path)

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

size = 4
kernel = np.ones((size, size), np.float32) / (size ** 2)
print(kernel)

dst = cv2.filter2D(image, -1, kernel)
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# [[0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]]

# %% [markdown]
# ## Blur

# %%
dst = cv2.blur(image, (6,10))
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2HSV))
plt.show()

# %%
lower_blue = np.array([0,0,140])
upper_blue = np.array([180,255,255])
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
plt.imshow(cv2.inRange(hsv, lower_blue , upper_blue))

# %% [markdown]
# # EXP

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
path = r'C:/Users/david/OneDrive/Escritorio/IAC/VA_Presentacion/blur/examples/gente.jpeg'
image = cv2.imread(path)

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
lower_red = np.array([160,100,50])
upper_red = np.array([180,255,255])
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
plt.imshow(cv2.inRange(hsv, lower_red , upper_red))

# %%
#mask_inv = cv2.bitwise_and(image, image, mask=hsv)

#res = cv2.bitwise_and(image, image, mask=hsv)
#background = cv2.bitwise_and(gray, gray, mask = mask_inv)

#background = np.stack((background,)*3, axis=-1)

#add_img = cv2.add(res, background)

# %%
#create a mask using the bounds set
mask = cv2.inRange(hsv, lower_red, upper_red)
#create an inverse of the mask
mask_inv = cv2.bitwise_not(mask)
#Filter only the red colour from the original image using the mask(foreground)
res = cv2.bitwise_and(image, image, mask=mask)
#Filter the regions containing colours other than red from the grayscale image(background)
background = cv2.bitwise_and(gray, gray, mask = mask_inv)
#convert the one channelled grayscale background to a three channelled image
background = np.stack((background,)*3, axis=-1)
#add the foreground and the background
added_img = cv2.add(res, background)

# %%
cv2.namedWindow("res", cv2.WINDOW_NORMAL)
cv2.namedWindow("hsv", cv2.WINDOW_NORMAL)
cv2.namedWindow("mask", cv2.WINDOW_NORMAL)
cv2.namedWindow("added", cv2.WINDOW_NORMAL)
cv2.namedWindow("back", cv2.WINDOW_NORMAL)
cv2.namedWindow("mask_inv", cv2.WINDOW_NORMAL)
cv2.namedWindow("gray", cv2.WINDOW_NORMAL)

# %%
cv2.imshow("back", background)
cv2.imshow("mask_inv", mask_inv)
cv2.imshow("added",added_img)
cv2.imshow("mask", mask)
cv2.imshow("gray", gray)
cv2.imshow("hsv", hsv)
cv2.imshow("res", res)

# %%
if cv2.waitKey(0):
    cv2.destroyAllWindows()
